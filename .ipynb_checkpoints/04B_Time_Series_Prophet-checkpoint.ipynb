# %%
#import libraries
import numpy as np
import pandas as pd
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt

from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
from pandas.plotting import autocorrelation_plot

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

import fbprophet
from fbprophet import Prophet
from fbprophet.plot import add_changepoints_to_plot
from fbprophet.diagnostics import cross_validation
from fbprophet.diagnostics import performance_metrics
from fbprophet.plot import plot_cross_validation_metric

# %matplotlib inline
plt.style.use('fivethirtyeight')

# %% [markdown]
# ## Data Prep

# %% [markdown]
# **Master**

# %%
master_df = pd.read_pickle('dt_master.pickle')

# %%
master_df.head(1)
# Out:
#             net_approval     Price  compound  sentiment  trump_kw  \
# 2017-01-23      4.400803  19799.85    0.4939        0.0     100.0
#
#             trump_mueller_kw
# 2017-01-23               0.0

# %% [markdown]
# **Approval Ratings**

# %%
dt_ratings = pd.read_pickle('dt_ratings.pickle')

# %%
dt_ratings.head(1)
# Out:
#             approve_estimate  disapprove_estimate  net_approval
# modeldate
# 2017-01-23         45.488977            41.088173      4.400803

# %% [markdown]
# **DJIA Price Data**

# %%
djia_df = pd.read_pickle('djia_data.pickle')

# %%
djia_df.columns
# Out:
# Index(['Price', 'Open', 'High', 'Low', 'Vol.', 'Change %'], dtype='object')

# %%
djia_df.head(1)
# Out:
#                Price       Open       High        Low    Vol. Change %
# Date
# 2019-01-18  24706.35  24,534.19  24,750.22  24,459.03  372.97    1.38%

# %% [markdown]
# **Trump Twitter Data**

# %%
dt_tweets = pd.read_pickle('dt_tweets.pickle')

# %%
dt_tweets.index = dt_tweets['date']

# %%
dt_tweets.head(1)
# Out:
#                                                          text       date  neg  \
# date
# 2017-01-23  Busy week planned with a heavy focus on jobs a... 2017-01-23  0.0
#
#               neu    pos  compound  sentiment
# date
# 2017-01-23  0.826  0.174    0.4939          0

# %% [markdown]
# ### Create Dataframes

# %% [markdown]
# **Convert to Format**

# %%
#DJIA Price Data
djia_price = pd.DataFrame({"ds": djia_df.index, "y": djia_df.Price})
djia_price.reset_index(drop = True, inplace = True)

# %%
#DJIA percent change
djia_percent = pd.DataFrame({"ds": djia_df.index, "y": djia_df['Change %']})
djia_percent['y'] = djia_percent['y'].apply(lambda x: x.replace('%', ''))
djia_percent.reset_index(drop = True, inplace = True)

# %%
#Approval Rating
approvals = pd.DataFrame({"ds": dt_ratings.index, "approvals": dt_ratings.approve_estimate})
approvals.reset_index(drop = True, inplace = True)

# %%
#Diapproval Rating
disapprovals = pd.DataFrame({"ds": dt_ratings.index, "y": dt_ratings.disapprove_estimate})
disapprovals.reset_index(drop = True, inplace = True)

# %%
#Net Approval Rating
net_rating = pd.DataFrame({"ds": dt_ratings.index, "y": dt_ratings.net_approval})
net_rating.reset_index(drop = True, inplace = True)

# %%
#Trump Google Trends
trump_kw = pd.DataFrame({"ds": master_df.index, "y": master_df.trump_kw})
trump_kw.reset_index(drop = True, inplace = True)

# %%
# Trump Mueller Google Trends
trump_mueller_kw = pd.DataFrame({"ds": master_df.index, "y": master_df.trump_mueller_kw})
trump_mueller_kw.reset_index(drop = True, inplace = True)

# %% [markdown]
# **Combined**

# %%
#DJIA Percent & Approvals Regressor
percent_approvals = djia_percent
percent_approvals['approvals'] = approvals.approvals

# %% [markdown]
# ### Split Data

# %%
#Split Data

train_djia = djia_per[:int(0.8*(len(djia_per)))]
test_djia = djia_per[int(0.8*(len(djia_per))):]

# %%
train_djiap = djia_price[:int(0.8*(len(djia_per)))]
test_djiap = djia_price[int(0.8*(len(djia_per))):]

# %% [markdown]
# ## Modeling

# %% [markdown]
# ###  Model 1 (Price)

# %%
djia_df['Price'].plot()

# %%
model = Prophet()
model.fit(djia_price);
future = model.make_future_dataframe(periods=105) #forecasting for 1 year from now.
forecast = model.predict(future)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /Users/Jaime/anaconda3/lib/python3.7/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
figure = model.plot(forecast)

# %%
df_cv = cross_validation(model, initial='365 days', horizon = '102 days')
df_cv.head()
# Out:
# INFO:fbprophet:Making 6 forecasts with cutoffs between 2018-01-26 00:00:00 and 2018-10-08 00:00:00
#           ds          yhat    yhat_lower    yhat_upper         y     cutoff
# 0 2018-01-29  26213.243010  26021.625363  26410.377051  26439.48 2018-01-26
# 1 2018-01-30  26244.795403  26054.102242  26442.558191  26076.89 2018-01-26
# 2 2018-01-31  26286.412955  26105.253734  26484.419607  26149.39 2018-01-26
# 3 2018-02-01  26327.767001  26144.588416  26490.888925  26186.71 2018-01-26
# 4 2018-02-02  26379.194481  26189.120157  26569.763171  25520.96 2018-01-26

# %%
df_p = performance_metrics(df_cv)
df_p.head()
# Out:
#     horizon            mse        rmse         mae      mape  coverage
# 289 10 days  834711.983374  913.625735  785.662567  0.031688  0.190476
# 290 11 days  845443.317672  919.479917  800.208488  0.032245  0.166667
# 362 11 days  875465.977155  935.663389  817.875839  0.032918  0.166667
# 78  11 days  897463.849735  947.345687  829.897780  0.033428  0.166667
# 6   11 days  947487.025078  973.389452  852.410802  0.034324  0.166667

# %% [markdown]
# ### Model 2 (Price - Not auto)

# %%
prophet_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 502 entries, 0 to 501
# Data columns (total 2 columns):
# ds    502 non-null datetime64[ns]
# y     502 non-null float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 7.9 KB

# %%
prophet_model = fbprophet.Prophet(changepoint_prior_scale=0.8)

# %%
prophet_model.fit(prophet_data)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
prophet_forecast = prophet_model.make_future_dataframe(periods=30, freq='D')
prophet_forecast = prophet_model.predict(prophet_forecast)
prophet_model.plot(prophet_forecast, xlabel = 'Date', ylabel = 'Stock Price')
plt.title('Future DJIA Prices')
# Out:
# Text(0.5,1,'Future DJIA Prices')

# %%
fig = prophet_model.plot_components(prophet_forecast)

# %%
#fig = prophet_model.plot(prophet_forecast)
#a = add_changepoints_to_plot(fig.gca(), prophet_model, prophet_forecast)

# %%
df_cv = cross_validation(prophet_model, initial='365 days', horizon = '100 days')
# Out:
# INFO:fbprophet:Making 6 forecasts with cutoffs between 2018-02-02 00:00:00 and 2018-10-10 00:00:00

# %%
df_cv.head()
# Out:
#           ds          yhat    yhat_lower    yhat_upper         y     cutoff
# 0 2018-02-05  26502.318635  26341.210279  26664.118824  24345.75 2018-02-02
# 1 2018-02-06  26530.445069  26367.399529  26687.520161  24912.77 2018-02-02
# 2 2018-02-07  26577.229472  26398.234147  26734.511014  24893.35 2018-02-02
# 3 2018-02-08  26618.327945  26436.792162  26786.671243  23860.46 2018-02-02
# 4 2018-02-09  26658.700505  26465.725388  26822.413686  24190.90 2018-02-02

# %%
df_p = performance_metrics(df_cv)
df_p.head()
# Out:
#     horizon           mse         rmse         mae      mape  coverage
# 213 10 days  1.198918e+06  1094.951367  889.405538  0.035938  0.170732
# 284 10 days  1.193646e+06  1092.541029  884.431080  0.035703  0.170732
# 145 11 days  1.153101e+06  1073.825577  866.556055  0.034997  0.170732
# 6   11 days  1.264533e+06  1124.514716  912.130262  0.036858  0.146341
# 214 11 days  1.250282e+06  1118.160220  896.766247  0.036240  0.170732

# %%
fig = plot_cross_validation_metric(df_cv, metric='mape')

# %% [markdown]
# ### Model 3 (Percent Change)

# %%
djia_percent.head(1)
# Out:
#           ds     y
# 0 2019-01-18  1.38

# %%
mod3 = Prophet()
mod3.fit(djia_percent)
forcast = mod3.predict(future)
fig = mod3.plot(forecast)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /Users/Jaime/anaconda3/lib/python3.7/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
df3_cv = cross_validation(mod3, initial='365 days', horizon = '100 days')
# Out:
# INFO:fbprophet:Making 6 forecasts with cutoffs between 2018-02-02 00:00:00 and 2018-10-10 00:00:00

# %%
df_p3 = performance_metrics(df3_cv)
df_p3.head()
# Out:
# /Users/Jaime/anaconda3/lib/python3.7/site-packages/fbprophet/diagnostics.py:255: RuntimeWarning: invalid value encountered in subtract
#   return np.hstack((prefix, (s[w:] - s[:-w]) / float(w)))  # right-aligned
#     horizon       mse      rmse       mae  mape  coverage
# 213 10 days  2.169876  1.473050  1.041639   inf  0.585366
# 284 10 days  2.164706  1.471294  1.034052   inf  0.585366
# 145 11 days  2.058020  1.434580  0.990244   inf  0.609756
# 6   11 days  2.054582  1.433381  0.982276   inf  0.609756
# 214 11 days  2.056536  1.434063  0.986073   inf  0.609756

# %%
fig = plot_cross_validation_metric(df3_cv, metric='mape')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-92c0436fd5a0> in <module>
# ----> 1 fig = plot_cross_validation_metric(df3_cv, metric='mape')
#
# NameError: name 'plot_cross_validation_metric' is not defined

# %% [markdown]
# ### Add Regressors

# %%
percent_approvals.head(1)
# Out:
#           ds     y  approvals
# 0 2019-01-18  1.38  45.488977

# %%
percent_approvals.approvals = percent_approvals.approvals.fillna(method='bfill')
